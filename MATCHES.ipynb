# %% [markdown]
# ## IPL Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('matches - matches.csv')

# %% [markdown]
# #### preview of the dataset using head function

# %%
data.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# #### matches played between and the winner of the match

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# #### Fetching rows and columns using iloc function. Here i used fancy indexing to fetch all the rows ans 3 columns

# %%
data.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# #### fetching all the matches of saeason 2010

# %%
data[data['season'] == 2010].head()
# Out:
#       id  season        city        date                        team1  \
# 174  175    2010      Mumbai  2010-03-12        Kolkata Knight Riders
# 175  176    2010      Mumbai  2010-03-13               Mumbai Indians
# 176  177    2010  Chandigarh  2010-03-13              Kings XI Punjab
# 177  178    2010     Kolkata  2010-03-14  Royal Challengers Bangalore
# 178  179    2010     Chennai  2010-03-14              Deccan Chargers
#
#                      team2            toss_winner toss_decision  result  \
# 174        Deccan Chargers        Deccan Chargers         field  normal
# 175       Rajasthan Royals         Mumbai Indians           bat  normal
# 176       Delhi Daredevils       Delhi Daredevils         field  normal
# 177  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 178    Chennai Super Kings        Deccan Chargers           bat  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# #### created a function to count no. of matches played in a season

# %%
def match_played_in_season(season):
    data[data['season'] ==season]
    return data[data['season'] == season].shape[0]

# %%
match_played_in_season(2011)
# Out:
# 73

# %% [markdown]
# #### filtered the data city wise and matches played after season 2010

# %%
 data[(data['city']=='Hyderabad') & (data['season'] >= 2010)].head()
# Out:
#     id  season       city        date                team1  \
# 0    1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 5    6    2017  Hyderabad  2017-04-09        Gujarat Lions
# 18  19    2017  Hyderabad  2017-04-17  Sunrisers Hyderabad
# 20  21    2017  Hyderabad  2017-04-19  Sunrisers Hyderabad
# 35  36    2017  Hyderabad  2017-04-30  Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# 35        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#     result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0   normal           0  Sunrisers Hyderabad           35               0
# ...

# %% [markdown]
# #### querying no. of wins per team

# %%
data.value_counts('winner')
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# dtype: int64

# %% [markdown]
# #### plotting a graph to show toss desicion after winning

# %%
data.value_counts('toss_decision').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='toss_decision'>

# %% [markdown]
# #### plotted a histogram to see the win margins by runs of matches

# %%
data.win_by_runs.plot(xlabel='runs',kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### counting the no. of matches played by each team

# %%
(data.team1.value_counts() + data.team2.value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %% [markdown]
# #### fetching the winner of each season

# %%
data.drop_duplicates('season', keep='last')[['season' , 'winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %% [markdown]
# #### first match played in all the venues

# %%
group=data.groupby('venue')

# %%
group.first()
# Out:
#                                                      id  season  \
# venue
# Barabati Stadium                                    186    2010
# Brabourne Stadium                                   176    2010
# Buffalo Park                                        138    2009
# De Beers Diamond Oval                               151    2009
# Dr DY Patil Sports Academy                           72    2008
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  313    2012
# Dubai International Cricket Stadium                 462    2014
# Eden Gardens                                         11    2017
# Feroz Shah Kotla                                     15    2017
# Green Park                                           49    2017
# Himachal Pradesh Cricket Association Stadium        225    2010
# Holkar Cricket Stadium                                4    2017
# JSCA International Stadium Complex                  441    2013
# ...
